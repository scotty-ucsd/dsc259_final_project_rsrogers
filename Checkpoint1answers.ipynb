# %% [markdown]
# ## Q1 Which of the three datasets did you choose? Why?

# %% [markdown]
# We chose the Power Outages dataset.  We were not particularly interested in food/recipes and the real-world nature/applicability of power outages, as opposed to matches in a video game, appealed to us, as well as the opportunities for visualization.

# %% [markdown]
# ## Q2 Upload a screenshot of a plotly visualization you’ve created while completing Part 1, Step 2: Data Cleaning and Exploratory Data Analysis.

# %% [markdown]
# Below are box plots, by month, for the distribution of outage durations

# %% [markdown]
# ![Box plots by month](duration_month.png)

# %% [markdown]
# ## Q3 What is the pair of hypotheses you plan on testing in Part 1, Step 4? What is the test statistic you plan on using?

# %% [markdown]
# ## Q4 What is the column you plan on trying to predict in Part 1, Steps 5-8? Is it a classification or regression problem?
